# %%
import pandas as pd
from sklearn.model_selection import train_test_split


canada_sars = pd.read_csv('sars_canada.csv')
canada_covid = pd.read_csv('covid_canada.csv')

display(canada_sars)
display(canada_covid)
# Out:
#          date country  popdata2003  new_cases  cumulative_cases  new_deaths  \
# 0   3/17/2003  Canada     31641630          8                 8           2
# 1   3/18/2003  Canada     31641630          0                 8           0
# 2   3/19/2003  Canada     31641630          0                 8           0
# 3   3/20/2003  Canada     31641630          1                 9           0
# 4   3/21/2003  Canada     31641630          0                 9           0
# ..        ...     ...          ...        ...               ...         ...
# 91   7/7/2003  Canada     31641630          0               251           0
# 92   7/8/2003  Canada     31641630          0               250           0
# 93   7/9/2003  Canada     31641630          0               249           0
# 94  7/10/2003  Canada     31641630          1               250           0
# 95  7/11/2003  Canada     31641630          0               250           0
#
#     cumulative_deaths
# 0                   2
# ...

# %%
# Splits the two data frames into training and test data, x and y values are not defined yet

sars_train, sars_test = train_test_split(canada_sars, test_size=.2, random_state = 8)
covid_train, covid_test = train_test_split(canada_covid, test_size=.2, random_state=8)

display(sars_train)
display(sars_test)
display(covid_train)
display(covid_test)
# Out:
#          date country  popdata2003  new_cases  cumulative_cases  new_deaths  \
# 34  4/25/2003  Canada     31641630          0               140           0
# 39   5/1/2003  Canada     31641630          0               147           0
# 16   4/4/2003  Canada     31641630          7                69           1
# 19   4/8/2003  Canada     31641630          1                91           1
# 50  5/14/2003  Canada     31641630          0               143           1
# ..        ...     ...          ...        ...               ...         ...
# 8   3/26/2003  Canada     31641630          8                19           0
# 90   7/4/2003  Canada     31641630          0               251           0
# 5   3/22/2003  Canada     31641630          0                 9           0
# 84  6/26/2003  Canada     31641630          1               251           0
# 67   6/3/2003  Canada     31641630         15               213           1
#
#     cumulative_deaths
# 34                 15
# ...
